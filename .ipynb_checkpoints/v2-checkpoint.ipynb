# %% [markdown]
# # The Goal of this Project
#
# *In this project, your goal is to write a software pipeline to identify the lane boundaries in a video from a front-facing camera on a car.*
#
# ## Project Steps
# 1. Camera calibration
# 2. Distortion Correction
# 3. Color Channels & Gradient Thresholding
# 4. Perspective Transform
# 5. Finding the lanes
# 6. Measuring Curvature

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# ### Camera Calibration

# %%
#read in n example calibration image
img = mpimg.imread('./camera_cal/calibration1.jpg')
plt.imshow(img)

# %% [markdown]
# #### Read in all calibration images and extract corner co-ords

# %%
import glob
# %matplotlib qt
#read in and make a list of calibration images
images = glob.glob('./camera_cal/calibration*.jpg')

#Arrays to store object points and image points from all the images
objpoints = []
imgpoints = []

# prepare object points
nx = 9#enter the number of inside corners in x
ny = 6#enter the number of inside corners in y

#prepare object points, like (0,0,0), (1,0,0,) ... (7,5,0)
objp = np.zeros((ny*nx, 3), np.float32)
objp[:,:2] = np.mgrid[0:nx, 0:ny].T.reshape(-1,2)

for fname in images:
    #read in each image
    img = mpimg.imread(fname)

    #convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    plt.imshow(img)

    # find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (nx,ny), None)
    
    #if points detected, add corners and object points
    if ret == True:
        imgpoints.append(corners)
        objpoints.append(objp)

        #draw and display the corners
        img = cv2.drawChessboardCorners(img,(nx,ny), corners, ret)
        plt.imshow(img)
        print("detected")
    else:
        print("not detected")
# Out:
# not detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# not detected
# not detected
# detected
# detected
# detected
# detected

# %% [markdown]
# #### Generate camera mtx and distortion mtx for image correction

# %%
# Calculate and return distortion coeffs (dist), 
# camera mtx (mtx) to transform 3d object points to 2D images, position of camera in world for rotation and translation vecs
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

# %% [markdown]
# ### Distortion Correction
# #### Correct images using camera and distortion matrix

# %%
#read in a calibration image & return undistored destination image
img1 = mpimg.imread('./camera_cal/calibration1.jpg')
dst = cv2.undistort(img1, mtx, dist, None, mtx)
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img1)
ax1.set_title('Distorted image')
ax2.imshow(dst)
ax2.set_title('Corrected image')
# Out:
# Text(0.5,1,'Corrected image')

# %% [markdown]
# ### Color Channels & Gradient Thresholding
#
# #### Some functions for calculating gradients and thresholding

# %%
def mag_thresh(img, sobel_kernel=3, mag_thresh=(0, 255)):
    #Applying the Sobel operator to an image is a way of taking the derivative 
    #of the image in the xx or yy direction

    #Pass a single color channel, first convert it to grayscale 
    #(Use cv2.COLOR_RGB2GRAY if you've read in an image using mpimg.imread(). 
    #Use cv2.COLOR_BGR2GRAY if you've read in an image using cv2.imread())
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    #Calculate the derivative in the xx direction (the 1, 0 at the end denotes xx direction)
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)

    #Calculate the derivative in the yy direction (the 0, 1 at the end denotes yy direction)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)

   
    gradmag = np.sqrt(sobelx**2 + sobely**2)
    # Rescale to 8 bit
    scale_factor = np.max(gradmag)/255 
    scaled_sobel = (gradmag/scale_factor).astype(np.uint8)

    #Create a binary threshold to select pixels based on gradient strength
    thresh_min = mag_thresh[0]
    thresh_max = mag_thresh[1]
    sxbinary = np.zeros_like(scaled_sobel)
    sxbinary[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    
    #plt.imshow(sxbinary, cmap='gray')
    return sxbinary

# %%
# Define a function to threshold an image for a given range and Sobel kernel
def dir_threshold(img, sobel_kernel=3, thresh=(0, np.pi/2)):
    # Grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Calculate the x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Take the absolute value of the gradient direction, 
    # apply a threshold, and create a binary image result
    absgraddir = np.arctan2(np.absolute(sobely), np.absolute(sobelx))
    binary_output =  np.zeros_like(absgraddir)
    binary_output[(absgraddir >= thresh[0]) & (absgraddir <= thresh[1])] = 1

    # Return the binary image
    return binary_output

# %%
def abs_sobel_thresh(img, orient='x', sobel_kernel=3, thresh=(0, 255)):
    # Calculate directional gradient
    # Apply threshold
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    
    if orient == 'x':
        #Calculate the derivative in the xx direction (the 1, 0 at the end denotes xx direction)
        sobel = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    else:
        #Calculate the derivative in the yy direction (the 0, 1 at the end denotes yy direction)
        sobel = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)

    #Calculate the absolute value of the xx derivative
    abs_sobel = np.absolute(sobel)

    #Convert the absolute value image to 8-bit
    scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
    
    #Create a binary threshold to select pixels based on gradient strength
    thresh_min = thresh[0]
    thresh_max = thresh[1]
    sxbinary = np.zeros_like(scaled_sobel)
    sxbinary[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    return sxbinary

# %%
# Define a function that thresholds the S-channel of HLS
def hls_select(img, channel='s', thresh=(0, 255)):
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    colour_options = {'s' : 2,
           'h' : 0,
           'l' : 1,}
        
    channel = hls[:,:,colour_options[channel]]
    binary_output = np.zeros_like(channel)
    binary_output[(channel > thresh[0]) & (channel <= thresh[1])] = 1
    return binary_output

# %% [markdown]
# #### Combining thresholds on greyscale images

# %%
# %matplotlib inline
fig = plt.figure(figsize=(80,70))
columns = 2
images = glob.glob('./test_images/test*.jpg')

# Choose a Sobel kernel size
ksize = 11 # Choose a larger odd number to smooth gradient measurements

for i, fname in enumerate(images):
    #read in each image
    img = mpimg.imread(fname)
    
    #convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply each of the thresholding functions
    gradx = abs_sobel_thresh(img, orient='x', sobel_kernel=15, thresh=(20, 100))
    grady = abs_sobel_thresh(img, orient='y', sobel_kernel=3, thresh=(0, 0))
    mag_binary = mag_thresh(img, sobel_kernel=3, mag_thresh=(30, 100))
    dir_binary = dir_threshold(img, sobel_kernel=15, thresh=(0.7, 1.3))
    
    combined = np.zeros_like(dir_binary)
    combined[((mag_binary == 1) & (dir_binary == 1))] = 1
    
    a=fig.add_subplot(len(images) / columns + 1, columns, i + 1)
    a.imshow(combined, cmap='gray')

# %% [markdown]
# #### Combining thresholds on HLS images

# %%
def proc_imag_hls_thresh(img):
    #convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply each of the thresholding functions
    sxbinary = abs_sobel_thresh(img, orient='x', sobel_kernel=15, thresh=(20, 100))
    s_binary = hls_select(img, channel='s', thresh=(170, 255))
    
    # Combine the two binary thresholds
    combined_binary = np.zeros_like(sxbinary)
    combined_binary[(s_binary == 1) | (sxbinary == 1)] = 1
    
    return combined_binary

# %%
# %matplotlib inline
fig = plt.figure(figsize=(80,70))
columns = 2
images = glob.glob('./test_images/test*.jpg')

# Choose a Sobel kernel size
ksize = 11 # Choose a larger odd number to smooth gradient measurements

image_final = []

for i, fname in enumerate(images):
    #read in each image
    img = mpimg.imread(fname)
    
    combined = proc_imag_hls_thresh(img)
    
    image_final = combined
    
    a=fig.add_subplot(len(images) / columns + 1, columns, i + 1)
    a.imshow(combined, cmap='gray')

# %% [markdown]
# ### Perspective Transform
#
# #### Calculate the perspective transform matrix and inverse perspective transform matrix

# %%
# Define a function that takes an image, number of x and y points, 
# camera matrix and distortion coefficients
def perspective_transform(img, src):
    
    offset = 100 # offset for dst points
    
    # Grab the image shape
    img_size = (gray.shape[1], gray.shape[0])
    
    #destination is same size as input image
    dst = np.float32([[offset, offset], [img_size[0]-offset, offset], 
                                     [img_size[0]-offset, img_size[1]-offset], 
                                     [offset, img_size[1]-offset]])

    # Given src and dst points, calculate the perspective transform matrix
    warp_mtx = cv2.getPerspectiveTransform(src, dst)
    
    # Given dst and src points, calculate the inverse perspective transform matrix
    inv_warp_mtx = cv2.getPerspectiveTransform(dst, src)
    
    # Warp the image using OpenCV warpPerspective()
    warped_image = cv2.warpPerspective(img, warp_mtx, img_size)

    # Return the resulting image and matrix
    return warped_image, warp_mtx, inv_warp_mtx

# %% [markdown]
# #### Process straight  line inage

# %%
#read in striaght line inage
sl_img = mpimg.imread('./test_images/straight_lines1.jpg')
src = np.float32([[435, 500], [845, 500], [1240, 650], [40, 650]])
pt_img, M, invM = perspective_transform(sl_img, src)
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(sl_img)
ax1.set_title('Original image')
ax2.imshow(pt_img)
ax2.set_title('Prespective Transformed image')
# Out:
# Text(0.5,1,'Prespective Transformed image')

# %% [markdown]
# #### Process slight curve line inage

# %%
#read in slight curve line inage
sl_img = mpimg.imread('./test_images/test3.jpg')
src = np.float32([[435, 500], [845, 500], [1240, 650], [40, 650]])
pt_img, M, invM = perspective_transform(sl_img, src)
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(sl_img)
ax1.set_title('Original image')
ax2.imshow(pt_img)
ax2.set_title('Prespective Transformed image')
# Out:
# Text(0.5,1,'Prespective Transformed image')

# %% [markdown]
# ### Finding the lines
#
# #### Histogram estimate of left and right line position at the bottom of the image

# %%
# %matplotlib inline
def calc_coldstart_lane_positions(img):
    # Assuming you have created a warped binary image called "binary_warped"
    # Take a histogram of the bottom half of the image
    histogram = np.sum(img[img.shape[0]//2:,:], axis=0)
   
    # Create an output image to draw on and  visualize the result
    out_img = np.dstack((img, img, img))*255
    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]//2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint
    
    return leftx_base, rightx_base, histogram

# %%
thres_img = proc_imag_hls_thresh(sl_img)
pt_img, M, invM = perspective_transform(thres_img, src)
leftx_base, rightx_base, histogram = calc_coldstart_lane_positions(pt_img)
plt.plot(histogram)
plt.title('Lane position estimate histogram')
plt.xlabel('x-axis pixel position')
plt.ylabel('Frequency of pixels activated')
plt.grid()

# %% [markdown]
# #### Window search for line points - from cold start

# %%
def coldstart_window_search(binary_warped, nwindows, leftx_base, rightx_base, margin=100, minpix=50):
    # # Choose the number of sliding windows
    # nwindows = 9
    # Set height of windows
    window_height = np.int(binary_warped.shape[0]//nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # # Set the width of the windows +/- margin
    # margin = 100
    # # Set minimum number of pixels found to recenter window
    # minpix = 50
    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []
    
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Draw the windows on the visualization image
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),
        (0,255,0), 2) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),
        (0,255,0), 2) 
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))
        
    return left_lane_inds, right_lane_inds, out_img

# %%
binary_warped = pt_img
left_lane_inds, right_lane_inds, out_img = coldstart_window_search(binary_warped, 9, leftx_base, rightx_base)

# %%
def fit_poly(binary_warped, left_lane_inds, right_lane_inds):
    # Concatenate the arrays of indices
    try:
        left_lane_inds = np.concatenate(left_lane_inds)
        right_lane_inds = np.concatenate(right_lane_inds)
    except:
        pass

    # Extract left and right line pixel positions
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 

    # Fit a second order polynomial to each
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)
    
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    
    lane_drift = deviation_lane_center_meters(left_fitx, right_fitx)
    left_curverad, right_curverad = curvature(binary_warped, left_fitx, right_fitx)
    avg_lane_width = np.mean(right_fitx-left_fitx)*3.7/600
    
    return left_fit, right_fit, left_lane_inds, right_lane_inds, lane_drift, left_curverad, right_curverad, avg_lane_width

# %%
left_fit, right_fit, left_lane_inds, right_lane_inds, lane_drift, left_curverad, right_curverad, avg_lane_width = fit_poly(binary_warped, left_lane_inds, right_lane_inds)

# Generate x and y values for plotting
ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]
plt.imshow(out_img)
plt.plot(left_fitx, ploty, color='yellow')
plt.plot(right_fitx, ploty, color='yellow')
plt.xlim(0, 1280)
plt.ylim(720, 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-395-069a2867ce5c> in <module>()
# ----> 1 left_fit, right_fit, left_lane_inds, right_lane_inds, lane_drift, left_curverad, right_curverad, avg_lane_width = fit_poly(binary_warped, left_lane_inds, right_lane_inds)
#       2
#       3 # Generate x and y values for plotting
#       4 ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
#       5 left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
#
# <ipython-input-394-cda30d8bc452> in fit_poly(binary_warped, left_lane_inds, right_lane_inds)
#      11     nonzeroy = np.array(nonzero[0])
#      12     nonzerox = np.array(nonzero[1])
# ---> 13     leftx = nonzerox[left_lane_inds]
#      14     lefty = nonzeroy[left_lane_inds]
#      15     rightx = nonzerox[right_lane_inds]
#
# ...

# %% [markdown]
# #### Search for line points - warm start uses previous polynomial fit to create search window

# %%
def warmstart_window_search(binary_warped, left_fit, right_fit, margin = 100):
    # Assume you now have a new warped binary image 
    # from the next frame of video (also called "binary_warped")
    # It's now much easier to find line pixels!
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    margin = 100
    left_lane_inds = ((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + 
    left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + 
    left_fit[1]*nonzeroy + left_fit[2] + margin))) 

    right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + 
    right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + 
    right_fit[1]*nonzeroy + right_fit[2] + margin)))  

    
    return left_lane_inds, right_lane_inds

# %%
def deviation_lane_center_meters(left_fitx, right_fitx):
    return (((right_fitx[-1]-left_fitx[-1])/2+left_fitx[-1]-640)*3.7/600)

# %%
left_lane_inds, right_lane_inds = warmstart_window_search(binary_warped, left_fit, right_fit)
left_fit, right_fit, left_lane_inds, right_lane_inds, lane_drift, left_curverad, right_curverad, avg_lane_width = fit_poly(binary_warped, left_lane_inds, right_lane_inds)

margin = 100

# Generate x and y values for plotting
ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

# Create an image to draw on and an image to show the selection window
out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
window_img = np.zeros_like(out_img)
# Color in left and right line pixels
out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

# Generate a polygon to illustrate the search window area
# And recast the x and y points into usable format for cv2.fillPoly()
left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
                              ploty])))])
left_line_pts = np.hstack((left_line_window1, left_line_window2))
right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
                              ploty])))])
right_line_pts = np.hstack((right_line_window1, right_line_window2))

# Draw the lane onto the warped blank image
cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)
print(str() #lane center
print(str(np.mean(right_fitx-left_fitx)*3.7/600)) #lane width average
print("lc:" + str(left_fit[2]))
plt.imshow(result)
plt.plot(left_fitx, ploty, color='yellow')
plt.plot(right_fitx, ploty, color='yellow')
plt.xlim(0, 1280)
plt.ylim(720, 0)
# Out:
#   File "<ipython-input-392-603cd81ab6bc>", line 34
#     print(str(np.mean(right_fitx-left_fitx)*3.7/600)) #lane width average
#         ^
# SyntaxError: invalid syntax

# %%
# Define conversions in x and y from pixels space to meters
def curvature(img, left_fit, right_fit):
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/600 # meters per pixel in x dimension

    ploty = np.linspace(0, img.shape[0]-1, img.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    y_eval = np.max(ploty)

    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(ploty*ym_per_pix, left_fitx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, right_fitx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    
    
    return left_curverad, right_curverad

left_curverad, right_curverad = curvature(binary_warped, left_fitx, right_fitx)
# Now our radius of curvature is in meters
print(left_curverad, 'm', right_curverad, 'm')
# Example values: 632.1 m    626.2 m
# Out:
# 225187393207.00406 m 1420948157408.1685 m

# %%
# Create an image to draw the lines on
warp_zero = np.zeros_like(binary_warped).astype(np.uint8)
color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

# Recast the x and y points into usable format for cv2.fillPoly()
pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
pts = np.hstack((pts_left, pts_right))

# Draw the lane onto the warped blank image
cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

# Warp the blank back to original image space using inverse perspective matrix (Minv)
newwarp = cv2.warpPerspective(color_warp, invM, (sl_img.shape[1], sl_img.shape[0])) 
# Combine the result with the original image
result = cv2.addWeighted(sl_img, 1, newwarp, 0.3, 0)
plt.imshow(result)

# %%
import cv2
print(cv2.__version__)
vidcap = cv2.VideoCapture('project_video.mp4')
success,image = vidcap.read()
count = 0
success = True
while success:
  cv2.imwrite("./output_images/input_frame%04d.jpg" % count, image)     # save frame as JPEG file
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# 3.4.1
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
def transform_back(binary_warped, original_image, left_fit, righ_fit, invM):
    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    
    # Create an image to draw the lines on
    warp_zero = np.zeros_like(binary_warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, invM, (original_image.shape[1], original_image.shape[0])) 
    # Combine the result with the original image
    result = cv2.addWeighted(original_image, 1, newwarp, 0.3, 0)
    
    return result

# %%
# Define a class to receive the characteristics of each line detection
class Line():
    def __init__(self):
        # was the line detected in the last iteration?
        self.detected = False  
        # line not detected in x attenpts
        self.attempts = 0
        # average frames
        self.avg_frames = 0
        # x values of the last n fits of the line
        self.recent_xfitted = [] 
        #average x values of the fitted line over the last n iterations
        self.bestx = None     
        #polynomial coefficients averaged over the last n iterations
        self.best_fit = None  
        #polynomial coefficients for the most recent fit
        self.current_fit = [np.array([False])]  
        #radius of curvature of the line in some units
        self.radius_of_curvature = None 
        #distance in meters of vehicle center from the line
        self.line_base_pos = None 
        #difference in fit coefficients between last and new fits
        self.diffs = np.array([0,0,0], dtype='float') 
        #x values for detected line pixels
        self.allx = None  
        #y values for detected line pixels
        self.ally = None

# %%
def line_detected(lane_drift, left_curverad, right_curverad, avg_lane_width):
    
    lane_drift_mean = 0.46
    lane_drift_std = 0.056
    lane_drift_zero = lane_drift-lane_drift_mean
    lane_drift_ok = (lane_drift_zero < 3*lane_drift_std) & (lane_drift_zero > - 3*lane_drift_std)
    
    lane_width_mean = 3.87
    lane_width_std = 0.042
    lane_width_zero = avg_lane_width-lane_width_mean
    lane_width_ok = (lane_width_zero < 3*lane_width_std) & (lane_width_zero > - 3*lane_width_std)
    
    min_radius_hw = 2445/3.28
    curvature_ok = (right_curverad > min_radius_hw) | (left_curverad > min_radius_hw)
    
    return lane_drift_ok & lane_width_ok & curvature_ok

# %%
fnames = glob.glob('./output_images/input_frame****.jpg')

# print(images)

output_img

lane_drift_arr = []
land_width_arra = []
curverad_ratio = []

line = Line()

alpha = 0.25


for i, fname in enumerate(fnames):
#     print(fname)

    image = mpimg.imread(fname)

    thres_img = proc_imag_hls_thresh(image)

    pt_img, M, invM = perspective_transform(thres_img, src)
    
    
    
    if line.detected == False:
        
        leftx_base, rightx_base, histogram = calc_coldstart_lane_positions(pt_img)
    
        left_lane_inds, right_lane_inds, out_img = coldstart_window_search(pt_img, 9, leftx_base, rightx_base)
#         print(left_lane_inds[0])
    else:
#         print(left_fit)
#         print(right_fit)
        left_lane_inds, right_lane_inds = warmstart_window_search(pt_img,left_fit, right_fit)
#         print(left_lane_inds)

    left_fit, right_fit, left_lane_inds, right_lane_inds, lane_drift, left_curverad, right_curverad, avg_lane_width  = fit_poly(pt_img, left_lane_inds, right_lane_inds)

    detected = line_detected(lane_drift, left_curverad, right_curverad, avg_lane_width)
    
    if detected:
        line.detected = True
        line.current_fit = (left_fit, right_fit)
        line.line_base_pos = avg_lane_width
        line.radius_of_curvature = (left_curverad, right_curverad)
        self.avg_frames = self.avg_frames + 1
        line.best_fit = line.current_fit*alpha + line.best_fit*(1.0-alpha)
    else:
        left_fit, right_fit = line.current_fit
        line.attempts = line.attempts +1
        if line.attempts > 3:
            line.detected = False
            line.attempts = 0
            self.avg_frames = 0
                
    if self.avg_frames > 10:
        left_fit, right_fit = line.best_fit
    else:
        left_fit, right_fit = line.current_fit
    
    #     print(left_fit)
#     print(right_fit)
    lane_drift_arr.append(lane_drift)
    land_width_arra.append(avg_lane_width)
    curverad_ratio.append(np.min((left_curverad,right_curverad))/np.max((left_curverad, right_curverad)))
    
#     print('lane drift: ', lane_drift)
    
#     print(left_curverad, 'm', right_curverad, 'm')
#     print(np.min((left_curverad,right_curverad))/np.max((left_curverad, right_curverad)), '/%d')

    output_img = transform_back(pt_img, image, left_fit, right_fit, invM)
    
    cv2.imwrite("./output_images/output_frame%04d.jpg" % i, output_img)     # save frame as JPEG file
    
#     if i == 25:
#         break
        
plt.imshow(output_img)

print('mean lane drift: ', np.mean(lane_drift_arr))
print('std lane drift: ', np.std(lane_drift_arr))

print('mean lane width: ', np.mean(land_width_arra))
print('std lane width: ', np.std(land_width_arra))

print('curverad ratio mean: ', np.mean(curverad_ratio))
print('curverad ratio std: ', np.std(curverad_ratio))
# Out:
#   File "<ipython-input-431-76bdedeb3235>", line 55
#     if line.attempts > 3:
#     ^
# IndentationError: unexpected indent

# %%
# fnames = glob.glob('./output_images/output_frame****.jpg')
# frame = cv2.imread(fnames[0])
# height, width, layers = frame.shape

# video = cv2.VideoWriter('output_video.avi', -1, 1, (width,height))

# for fname in fnames:
# #     print(fname)
#     video.write(cv2.imread(fname))
    
# video.release()

# %%
import imageio
fileList = sorted(glob.glob('./output_images/output_frame*.jpg'))
writer = imageio.get_writer('project_video_out.mp4', fps=20)

for im in fileList:
    writer.append_data(imageio.imread(im))
writer.close()
